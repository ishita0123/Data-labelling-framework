# %%
filepath=input()
# Out:
# C:\Users\admin\Desktop\spam\data.csv

# %%
import pandas as pd
df=pd.read_csv(filepath)

# %%
df
# Out:
#       Unnamed: 0            author                        date  \
# 0              0  Alessandro leite         2014-11-05T22:21:36
# 1              1      Salim Tayara         2014-11-02T14:33:30
# 2              2           Phuc Ly         2014-01-20T15:27:47
# 3              3      DropShotSk8r         2014-01-19T04:27:18
# 4              4            css403         2014-11-07T14:25:48
# ...          ...               ...                         ...
# 1581         443      Themayerlife                         NaN
# 1582         444       Fill Reseni  2015-05-27T17:10:53.724000
# 1583         445    Greg Fils Aimé                         NaN
# 1584         446             Lil M                         NaN
# 1585         447       AvidorFilms                         NaN
#
#                                                    text  label  video
# 0     pls http://www10.vakinha.com.br/VaquinhaE.aspx...   -1.0      1
# 1     if your like drones, plz subscribe to Kamal Ta...   -1.0      1
# 2                        go here to check the views :3﻿   -1.0      1
# 3               Came here to check the views, goodbye.﻿   -1.0      1
# 4                         i am 2,126,492,636 viewer :D﻿   -1.0      1
# ...                                                 ...    ...    ...
# 1581                         Check out my mummy chanel!   -1.0      4
# 1582               The rap: cool     Rihanna: STTUUPID﻿   -1.0      4
# 1583  I hope everyone is in good spirits I&#39;m a h...   -1.0      4
# 1584  Lil m !!!!! Check hi out!!!!! Does live the wa...   -1.0      4
# 1585  Please check out my youtube channel! Just uplo...   -1.0      4
#
# [1586 rows x 6 columns]

# %%
from rules import *

# %%
#lfs

# %%
from snorkel.labeling import PandasLFApplier, LFAnalysis
from snorkel.labeling.model import LabelModel

applier = PandasLFApplier(lfs)
L_train = applier.apply(df)
label_model = LabelModel(cardinality=2, verbose=True)
label_model.fit(L_train, n_epochs=5000, seed=123, log_freq=20, lr=0.01)
preds_train = label_model.predict(L_train)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1586/1586 [00:00<00:00, 4950.03it/s]

# %%
from snorkel.labeling import filter_unlabeled_dataframe
pd.set_option('mode.chained_assignment', None)
df_filtered, preds_train_filtered = filter_unlabeled_dataframe(
    df, preds_train, L_train
)
df_filtered["label"] = preds_train_filtered

# %%
df_filtered
# Out:
#       Unnamed: 0                                author                 date  \
# 0              0                      Alessandro leite  2014-11-05T22:21:36
# 1              1                          Salim Tayara  2014-11-02T14:33:30
# 2              2                               Phuc Ly  2014-01-20T15:27:47
# 3              3                          DropShotSk8r  2014-01-19T04:27:18
# 5              5                          Giang Nguyen  2014-11-06T04:55:41
# ...          ...                                   ...                  ...
# 1580         442  TMCB production (Instrumental Beats)                  NaN
# 1581         443                          Themayerlife                  NaN
# 1583         445                        Greg Fils Aimé                  NaN
# 1584         446                                 Lil M                  NaN
# 1585         447                           AvidorFilms                  NaN
#
#                                                    text  label  video
# 0     pls http://www10.vakinha.com.br/VaquinhaE.aspx...      0      1
# 1     if your like drones, plz subscribe to Kamal Ta...      0      1
# 2                        go here to check the views :3﻿      1      1
# 3               Came here to check the views, goodbye.﻿      1      1
# 5                   https://www.facebook.com/teeLaLaLa﻿      0      1
# ...                                                 ...    ...    ...
# 1580            Check out our Channel for nice Beats!!﻿      1      4
# 1581                         Check out my mummy chanel!      1      4
# 1583  I hope everyone is in good spirits I&#39;m a h...      1      4
# 1584  Lil m !!!!! Check hi out!!!!! Does live the wa...      1      4
# 1585  Please check out my youtube channel! Just uplo...      1      4
#
# [758 rows x 6 columns]

# %%
df_filtered.to_csv('output.csv')
